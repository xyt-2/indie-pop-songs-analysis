# %% [markdown]
# #### No need to run the following section if you have run the following code in your terminal:
#
# ```
# pip install -r final-project/requirements.txt
# ```

# %%
pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: spotipy in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from -r ../requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: requests in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from -r ../requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: Pandas in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from -r ../requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: NumPy in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from -r ../requirements.txt (line 4)) (1.26.2)
# Requirement already satisfied: Matplotlib in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from -r ../requirements.txt (line 5)) (3.8.2)
# Requirement already satisfied: Seaborn in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from -r ../requirements.txt (line 6)) (0.13.0)
# Requirement already satisfied: redis>=3.5.3 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from spotipy->-r ../requirements.txt (line 1)) (5.0.1)
# Requirement already satisfied: six>=1.15.0 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from spotipy->-r ../requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from spotipy->-r ../requirements.txt (line 1)) (1.26.18)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from requests->-r ../requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from requests->-r ../requirements.txt (line 2)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from requests->-r ../requirements.txt (line 2)) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from Pandas->-r ../requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from Pandas->-r ../requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from Pandas->-r ../requirements.txt (line 3)) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from Matplotlib->-r ../requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from Matplotlib->-r ../requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from Matplotlib->-r ../requirements.txt (line 5)) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from Matplotlib->-r ../requirements.txt (line 5)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from Matplotlib->-r ../requirements.txt (line 5)) (23.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from Matplotlib->-r ../requirements.txt (line 5)) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from Matplotlib->-r ../requirements.txt (line 5)) (3.1.1)
# Requirement already satisfied: async-timeout>=4.0.2 in /opt/anaconda3/envs/test/lib/python3.10/site-packages (from redis>=3.5.3->spotipy->-r ../requirements.txt (line 1)) (4.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Collection
#
# we obtained the raw data for our project by collect data from a [Spotify-made "Indie Pop Hits" playlist](https://open.spotify.com/playlist/37i9dQZF1DXbO6rt3GhXDY?si=4c33da4bfe5c4b73) using available spotify API and library, as well as web-scraping from website : 'https://www.indieshuffle.com/songs/indie-pop/' using Python libraries like BeautifulSoup and requests
#
# Due to the dynamic changes in the music industry, we chose to scrape data from dynamically generated pages. To get the most up-to-date collection of songs, you can run the following code. For the purpose of this project, please consider using files provided in the data folder, in the case of inconsistent result for the following sections (Cleaning, Analysis, Visualization).

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import requests
from requests.auth import HTTPBasicAuth

# %%
cid = 'c27327d3d3b44e06952699bd3024e1dd'
secret = '5b85ba25bdf2400199c183932bb036e2'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
import json
import pandas as pd

# %% [markdown]
# ### function(s) for both groups

# %%
# creating dataframe with audio features with list of tracks:
def create_audio_feature_df(tracks):
  track_ids = [track['id'] for track in tracks]
  audio_features = [sp.audio_features(track_id)[0] for track_id in track_ids]
  return pd.DataFrame(audio_features)

# %% [markdown]
# ### GROUP 1 Spotify-made Playlist
# unpersonalized playlist ("Indie Pop Hits")
#
# n=100

# %%
#Retrieve the playlist: "Indie Pop Hits" using its uri
playlist_tracks = sp.playlist_tracks("37i9dQZF1DXbO6rt3GhXDY")

# %%
# creating track database
g1_tracks = []
for item in playlist_tracks['items']:
  g1_tracks.append(item['track'])

group1_df = pd.DataFrame(g1_tracks)

# %%
# creating audio features df using list of track_ids
g1_audio_df = create_audio_feature_df(g1_tracks)
g1_audio_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.764   0.705    3    -5.279     0       0.0278        0.0371
# 1         0.603   0.784    6    -4.023     1       0.0620        0.4460
# 2         0.744   0.619    0    -9.805     1       0.0390        0.5980
# 3         0.815   0.518    7    -6.594     0       0.0897        0.2230
# 4         0.863   0.631    7    -4.689     1       0.0534        0.3050
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000019    0.0943    0.672  101.003  audio_features
# 1          0.000008    0.1190    0.769  172.041  audio_features
# 2          0.003720    0.2310    0.641  112.997  audio_features
# 3          0.000000    0.1040    0.877  151.891  audio_features
# 4          0.000030    0.1230    0.817  128.977  audio_features
#
#                        id                                   uri  \
# 0  0y60itmpH0aPKsFiGxmtnh  spotify:track:0y60itmpH0aPKsFiGxmtnh
# 1  3EaJDYHA0KnX88JvDhL9oa  spotify:track:3EaJDYHA0KnX88JvDhL9oa
# 2  7B3z0ySL9Rr0XvZEAjWZzM  spotify:track:7B3z0ySL9Rr0XvZEAjWZzM
# 3  0uI7yAKUf52Cn7y3sYyjiX  spotify:track:0uI7yAKUf52Cn7y3sYyjiX
# 4  4nK5YrxbMGZstTLbvj6Gxw  spotify:track:4nK5YrxbMGZstTLbvj6Gxw
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0y60itmpH0aP...
# 1  https://api.spotify.com/v1/tracks/3EaJDYHA0KnX...
# 2  https://api.spotify.com/v1/tracks/7B3z0ySL9Rr0...
# 3  https://api.spotify.com/v1/tracks/0uI7yAKUf52C...
# 4  https://api.spotify.com/v1/tracks/4nK5YrxbMGZs...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0y60...       196520
# 1  https://api.spotify.com/v1/audio-analysis/3EaJ...       173104
# 2  https://api.spotify.com/v1/audio-analysis/7B3z...       188387
# 3  https://api.spotify.com/v1/audio-analysis/0uI7...       177667
# 4  https://api.spotify.com/v1/audio-analysis/4nK5...       223480
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
# combining track df and track audio feature df
group1_combined = group1_df.merge(g1_audio_df,on="uri")
group1_combined.columns
# Out:
# Index(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms_x',
#        'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id_x',
#        'is_local', 'name', 'popularity', 'preview_url', 'track',
#        'track_number', 'type_x', 'uri', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'type_y', 'id_y', 'track_href',
#        'analysis_url', 'duration_ms_y', 'time_signature'],
#       dtype='object')

# %%
# exporting
group1_combined.to_csv('../data/raw/new_group1_raw.csv')

# %% [markdown]
# ### GROUP 2 WEB SCRAPE
# songs featured on indieshuffle.com
#
# n = 133

# %%
from bs4 import BeautifulSoup
import requests
import html
import re

# %%
base_url = 'https://www.indieshuffle.com/songs/indie-pop/'

# %%
# function to extract song info in html format info into tuple
def extract_song_info(text):
  text = " ".join(line.strip() for line in text.splitlines())
  text = html.unescape(text)
  extract = "<h5>.*<strong>(.*)</strong>.*</span>(.*)</h5>"
  return re.findall(extract, text)

# %%
# extracting songs from the first n pages using beautiful soup into list of tuples
n = 26
song_elements = []
for n in range(1,n):
  url = f'{base_url}page/+{n}'
  res = requests.get(url)
  soup = BeautifulSoup(res.text)
  song_elements += soup.find_all('h5')

song_tuple_list = []
for element in song_elements:
  song_tuple_list += extract_song_info(str(element))

len(song_tuple_list)
# Out:
# 200

# %%
g2_list = []
for artist_name, song_name in song_tuple_list:
    track_dict = sp.search(q='artist:' + artist_name + ', album:' + song_name, type="track", limit=1)
    g2_list.append(track_dict['tracks'])

# %%
g2_tracks=[]
n=0
for element in g2_list:
  try:
    g2_tracks.append(element['items'][0])
  except IndexError:
    n+=1
print(f'{n} tracks not found.')
# Out:
# 68 tracks not found.

# %%
# creating audio features df using list of track_ids
g2_audio_df = create_audio_feature_df(g2_tracks)
g2_audio_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.766   0.335    6   -12.630     1       0.0306         0.461
# 1         0.668   0.475    7    -7.663     1       0.0325         0.442
# 2         0.492   0.601    8    -9.432     1       0.0360         0.593
# 3         0.694   0.676    5    -6.631     1       0.0350         0.495
# 4         0.829   0.590    1    -9.050     1       0.3140         0.063
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.028300    0.1060    0.322  100.007  audio_features
# 1          0.000337    0.0997    0.586  111.993  audio_features
# 2          0.436000    0.1070    0.444  147.914  audio_features
# 3          0.000002    0.3560    0.666   96.085  audio_features
# 4          0.021800    0.0609    0.804   98.050  audio_features
#
#                        id                                   uri  \
# 0  0Yu6DQYBpvztT117wT37aR  spotify:track:0Yu6DQYBpvztT117wT37aR
# 1  0HvbFmfFlcsAJ6hydqflNk  spotify:track:0HvbFmfFlcsAJ6hydqflNk
# 2  3BqpakuX85Wtw8DI1yUr4q  spotify:track:3BqpakuX85Wtw8DI1yUr4q
# 3  4XyTTV4598arHa8KRcgPPF  spotify:track:4XyTTV4598arHa8KRcgPPF
# 4  46OGrRCC0Y7ZyF0qvXsPNt  spotify:track:46OGrRCC0Y7ZyF0qvXsPNt
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0Yu6DQYBpvzt...
# 1  https://api.spotify.com/v1/tracks/0HvbFmfFlcsA...
# 2  https://api.spotify.com/v1/tracks/3BqpakuX85Wt...
# 3  https://api.spotify.com/v1/tracks/4XyTTV4598ar...
# 4  https://api.spotify.com/v1/tracks/46OGrRCC0Y7Z...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0Yu6...       267125
# 1  https://api.spotify.com/v1/audio-analysis/0Hvb...       190148
# 2  https://api.spotify.com/v1/audio-analysis/3Bqp...       208658
# 3  https://api.spotify.com/v1/audio-analysis/4XyT...       124120
# 4  https://api.spotify.com/v1/audio-analysis/46OG...       195918
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
# combining track df and track audio feature df
group2_combined = group2_df.merge(g2_audio_df,on="uri")
group2_combined.columns
# Out:
# Index(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms_x',
#        'explicit', 'external_ids', 'external_urls', 'href', 'id_x', 'is_local',
#        'name', 'popularity', 'preview_url', 'track_number', 'type_x', 'uri',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type_y', 'id_y', 'track_href', 'analysis_url', 'duration_ms_y',
#        'time_signature'],
#       dtype='object')

# %%
# exporting
group2_combined.to_csv('../data/raw/new_group2_raw.csv')

# %% [markdown]
# ### GROUP 3 JINZY's songs
# n=7

# %%
# JINZY (URI: 7aCnUh8mmQKLeFl3bTtfFl) information
jinzy_top_tracks = sp.artist_top_tracks("7aCnUh8mmQKLeFl3bTtfFl")
group3_df = pd.DataFrame.from_dict(jinzy_top_tracks['tracks'])
group3_df
# Out:
#                                                album  \
# 0  {'album_type': 'single', 'artists': [{'externa...
# 1  {'album_type': 'single', 'artists': [{'externa...
# 2  {'album_type': 'single', 'artists': [{'externa...
# 3  {'album_type': 'single', 'artists': [{'externa...
# 4  {'album_type': 'single', 'artists': [{'externa...
# 5  {'album_type': 'single', 'artists': [{'externa...
# 6  {'album_type': 'single', 'artists': [{'externa...
# 7  {'album_type': 'single', 'artists': [{'externa...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
# 5  [{'external_urls': {'spotify': 'https://open.s...            1
# 6  [{'external_urls': {'spotify': 'https://open.s...            1
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 0       212653      True  {'isrc': 'QZMEN2027923'}
# 1       184277     False  {'isrc': 'QZK6H2278643'}
# 2       195716      True  {'isrc': 'QZNWY2265350'}
# 3       241668     False  {'isrc': 'QZMEM2216784'}
# 4       244305     False  {'isrc': 'QZK6G2278289'}
# 5       239399      True  {'isrc': 'QZMEP2167730'}
# 6       194857     False  {'isrc': 'QZMEM2216786'}
# 7       190870     False  {'isrc': 'QZMEM2216785'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/2k...
# 1  {'spotify': 'https://open.spotify.com/track/4G...
# 2  {'spotify': 'https://open.spotify.com/track/5H...
# 3  {'spotify': 'https://open.spotify.com/track/6l...
# 4  {'spotify': 'https://open.spotify.com/track/2e...
# 5  {'spotify': 'https://open.spotify.com/track/7a...
# 6  {'spotify': 'https://open.spotify.com/track/5D...
# 7  {'spotify': 'https://open.spotify.com/track/68...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/2kktCN1EnBf2...  2kktCN1EnBf2dvIm5ZkdI3
# 1  https://api.spotify.com/v1/tracks/4GK4ozFpzroP...  4GK4ozFpzroPxiUdE0k9yJ
# 2  https://api.spotify.com/v1/tracks/5HhLzu81uxhW...  5HhLzu81uxhWiyhvC0dHEO
# 3  https://api.spotify.com/v1/tracks/6lmOTdlIGSSE...  6lmOTdlIGSSEd55GLML2lZ
# 4  https://api.spotify.com/v1/tracks/2ep2fSZcVZxd...  2ep2fSZcVZxdOTalVbXbCa
# 5  https://api.spotify.com/v1/tracks/7aAqZRdwLXzW...  7aAqZRdwLXzW1LejPLC79I
# 6  https://api.spotify.com/v1/tracks/5DF1RA2Grkga...  5DF1RA2Grkga0mXk3WPStH
# 7  https://api.spotify.com/v1/tracks/68avRHl0QLfN...  68avRHl0QLfNwBUtZH8Aao
#
#    is_local  is_playable                        name  popularity  \
# 0     False         True  I Left the City That Night          27
# 1     False         True                    The Show           2
# 2     False         True         5 o'clock somewhere           1
# 3     False         True                    Firework           1
# 4     False         True             Turing's Secret           0
# 5     False         True                    Sin City           0
# 6     False         True                         Joi           0
# 7     False         True                   Forgotten           0
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/b9cd53b59caab09f...             1  track
# 1  https://p.scdn.co/mp3-preview/8cbc7a255d3011db...             1  track
# 2  https://p.scdn.co/mp3-preview/2a53f26e477f92dc...             1  track
# 3  https://p.scdn.co/mp3-preview/319de7760ed18db7...             1  track
# 4  https://p.scdn.co/mp3-preview/6a56bfb8ec37f287...             1  track
# 5  https://p.scdn.co/mp3-preview/27115fd597018560...             1  track
# 6  https://p.scdn.co/mp3-preview/0565f3f289eaa120...             3  track
# 7  https://p.scdn.co/mp3-preview/0f1538a911d7b800...             2  track
#
#                                     uri
# 0  spotify:track:2kktCN1EnBf2dvIm5ZkdI3
# 1  spotify:track:4GK4ozFpzroPxiUdE0k9yJ
# 2  spotify:track:5HhLzu81uxhWiyhvC0dHEO
# 3  spotify:track:6lmOTdlIGSSEd55GLML2lZ
# 4  spotify:track:2ep2fSZcVZxdOTalVbXbCa
# 5  spotify:track:7aAqZRdwLXzW1LejPLC79I
# 6  spotify:track:5DF1RA2Grkga0mXk3WPStH
# 7  spotify:track:68avRHl0QLfNwBUtZH8Aao

# %%
# getting audio feature from function (alt to previous cell)
g3_tracks = []
for item in jinzy_top_tracks['tracks']:
  g3_tracks.append(item)

g3_audio_df = create_audio_feature_df(g3_tracks)
g3_audio_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.525   0.575    4    -7.785     0       0.0470        0.4630
# 1         0.696   0.485    4    -5.913     0       0.0788        0.2860
# 2         0.798   0.559   11    -5.729     1       0.0343        0.5610
# 3         0.743   0.435    1   -11.530     1       0.0411        0.0522
# 4         0.440   0.516    5    -6.384     0       0.0710        0.4800
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.001850    0.0892   0.0739  158.084  audio_features
# 1          0.000000    0.3210   0.5120  171.984  audio_features
# 2          0.000000    0.1300   0.8750  119.998  audio_features
# 3          0.000996    0.0755   0.0843  111.892  audio_features
# 4          0.000000    0.0996   0.1690  148.005  audio_features
#
#                        id                                   uri  \
# 0  2kktCN1EnBf2dvIm5ZkdI3  spotify:track:2kktCN1EnBf2dvIm5ZkdI3
# 1  4GK4ozFpzroPxiUdE0k9yJ  spotify:track:4GK4ozFpzroPxiUdE0k9yJ
# 2  5HhLzu81uxhWiyhvC0dHEO  spotify:track:5HhLzu81uxhWiyhvC0dHEO
# 3  6lmOTdlIGSSEd55GLML2lZ  spotify:track:6lmOTdlIGSSEd55GLML2lZ
# 4  2ep2fSZcVZxdOTalVbXbCa  spotify:track:2ep2fSZcVZxdOTalVbXbCa
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2kktCN1EnBf2...
# 1  https://api.spotify.com/v1/tracks/4GK4ozFpzroP...
# 2  https://api.spotify.com/v1/tracks/5HhLzu81uxhW...
# 3  https://api.spotify.com/v1/tracks/6lmOTdlIGSSE...
# 4  https://api.spotify.com/v1/tracks/2ep2fSZcVZxd...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2kkt...       212654
# 1  https://api.spotify.com/v1/audio-analysis/4GK4...       184277
# 2  https://api.spotify.com/v1/audio-analysis/5HhL...       195717
# 3  https://api.spotify.com/v1/audio-analysis/6lmO...       241668
# 4  https://api.spotify.com/v1/audio-analysis/2ep2...       244305
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
group3_combined = group3_df.merge(g3_audio_df,on="uri")
group3_combined.head()
# Out:
#                                                album  \
# 0  {'album_type': 'single', 'artists': [{'externa...
# 1  {'album_type': 'single', 'artists': [{'externa...
# 2  {'album_type': 'single', 'artists': [{'externa...
# 3  {'album_type': 'single', 'artists': [{'externa...
# 4  {'album_type': 'single', 'artists': [{'externa...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms_x  explicit              external_ids  \
# 0         212653      True  {'isrc': 'QZMEN2027923'}
# 1         184277     False  {'isrc': 'QZK6H2278643'}
# 2         195716      True  {'isrc': 'QZNWY2265350'}
# 3         241668     False  {'isrc': 'QZMEM2216784'}
# 4         244305     False  {'isrc': 'QZK6G2278289'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/2k...
# 1  {'spotify': 'https://open.spotify.com/track/4G...
# 2  {'spotify': 'https://open.spotify.com/track/5H...
# 3  {'spotify': 'https://open.spotify.com/track/6l...
# 4  {'spotify': 'https://open.spotify.com/track/2e...
#
#                                                 href                    id_x  \
# 0  https://api.spotify.com/v1/tracks/2kktCN1EnBf2...  2kktCN1EnBf2dvIm5ZkdI3
# 1  https://api.spotify.com/v1/tracks/4GK4ozFpzroP...  4GK4ozFpzroPxiUdE0k9yJ
# 2  https://api.spotify.com/v1/tracks/5HhLzu81uxhW...  5HhLzu81uxhWiyhvC0dHEO
# 3  https://api.spotify.com/v1/tracks/6lmOTdlIGSSE...  6lmOTdlIGSSEd55GLML2lZ
# 4  https://api.spotify.com/v1/tracks/2ep2fSZcVZxd...  2ep2fSZcVZxdOTalVbXbCa
#
#    is_local  ...  instrumentalness liveness  valence    tempo          type_y  \
# 0     False  ...          0.001850   0.0892   0.0739  158.084  audio_features
# 1     False  ...          0.000000   0.3210   0.5120  171.984  audio_features
# 2     False  ...          0.000000   0.1300   0.8750  119.998  audio_features
# 3     False  ...          0.000996   0.0755   0.0843  111.892  audio_features
# 4     False  ...          0.000000   0.0996   0.1690  148.005  audio_features
#
#                      id_y                                         track_href  \
# 0  2kktCN1EnBf2dvIm5ZkdI3  https://api.spotify.com/v1/tracks/2kktCN1EnBf2...
# 1  4GK4ozFpzroPxiUdE0k9yJ  https://api.spotify.com/v1/tracks/4GK4ozFpzroP...
# 2  5HhLzu81uxhWiyhvC0dHEO  https://api.spotify.com/v1/tracks/5HhLzu81uxhW...
# 3  6lmOTdlIGSSEd55GLML2lZ  https://api.spotify.com/v1/tracks/6lmOTdlIGSSE...
# 4  2ep2fSZcVZxdOTalVbXbCa  https://api.spotify.com/v1/tracks/2ep2fSZcVZxd...
#
#                                         analysis_url  duration_ms_y  \
# 0  https://api.spotify.com/v1/audio-analysis/2kkt...         212654
# 1  https://api.spotify.com/v1/audio-analysis/4GK4...         184277
# 2  https://api.spotify.com/v1/audio-analysis/5HhL...         195717
# 3  https://api.spotify.com/v1/audio-analysis/6lmO...         241668
# 4  https://api.spotify.com/v1/audio-analysis/2ep2...         244305
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# [5 rows x 34 columns]

# %%
group3_combined.to_csv('../data/raw/new_group3_raw.csv')
